# %%
import pandas
import numpy
import requests
import random

# %%
# https://stackoverflow.com/questions/18834636/random-word-generator-python

word_site = "http://svnweb.freebsd.org/csrg/share/dict/words?view=co&content-type=text/plain"

response = requests.get(word_site)
WORDS = response.content.splitlines()

# %%
word_list = [x.decode('utf-8') for x in WORDS]
word_list[0:10]
# Out:
# ['a',
#  'AAA',
#  'AAAS',
#  'aardvark',
#  'Aarhus',
#  'Aaron',
#  'ABA',
#  'Ababa',
#  'aback',
#  'abacus']

# %%
row_ct = 1000
col_ct = 40

# %%
col_list=[]
for indx in range(col_ct):
    col_list.append(random.choice(word_list))

# %%
df = pandas.DataFrame(numpy.random.randint(0,100,size=(row_ct, col_ct)),columns=col_list)
df.shape
# Out:
# (1000, 40)

# %%
df.head()
# Out:
#    delude  antique  Pergamon  directory  integrate  pectoral  wiener  \
# 0      89       71        63         19         43        46      37
# 1      20       79        55         17         65        81       7
# 2      15       45        66         89          9        51      81
# 3      58       32        15         85         34        88      33
# 4       7       30        18         13         21        44      40
#
#    inconstant  quack  slob   ...     Seneca  ropy  Roseland  frog  playa  \
# 0          23     94    30   ...         60    16        35    65     70
# 1          13     97    19   ...         49    83         4    35     57
# 2          21     27    33   ...         10    31        78    55     45
# 3          77     52    90   ...          0    72        73    97     82
# 4          52     70    21   ...         46    25         6    17     75
#
#    handicraftsman  linoleic  scorpion  trill  migrate
# 0              40        61        84     67        7
# 1              59        80        79     65       97
# 2              14        52        12     33        8
# 3              90        99        93     25       82
# 4              34        84        70     26       85
#
# [5 rows x 40 columns]

# %%
for col in df.columns:
    for indx in range(df.shape[0]//2):
        df.loc[df.sample(1).index,col] = random.choice(word_list)

# %%
df.head()
# Out:
#   delude antique      Pergamon directory integrate pectoral      wiener  \
# 0     89      71            63        19        43  debauch   stablemen
# 1   lime   plait  transmitting        17     dogma       81           7
# 2     15      45       keynote        89         9       51          81
# 3     58      32            15        85  heavyset       88  equanimity
# 4      7      30        docket        13        21       44          40
#
#   inconstant       quack        slob   ...      Seneca     ropy Roseland  \
# 0       solo     actinic  gregarious   ...          60  conifer       35
# 1         13          97          19   ...          49       83   devour
# 2    shallot          27     dropout   ...          10       31       78
# 3         77  southbound          90   ...    blowfish       72       73
# 4       peer          70          21   ...          46    borax    sprue
#
#       frog   playa handicraftsman    linoleic     scorpion         trill  \
# 0       65      70         halide        dump          pup            67
# 1   weight     wit     volumetric  arithmetic           79            65
# 2  percept      45          worst       craft           12  childbearing
# 3       97  nuclei          batch          99  matriarchal            25
# 4       17      75             34   printmake           70          over
#
#   migrate
# 0       7
# 1      97
# 2       8
# 3      82
# 4      85
#
# [5 rows x 40 columns]

# %%
with open('file_to_parse.csv','w') as fil:
    for col in df.columns[:-1]:
        fil.write(col+', ')
    fil.write(df.columns[-1])
    fil.write("\n")
    for indx in range(df.shape[0]):
        fil.write(str(df.at[indx,df.columns[0]])+" : ")
        for col in range(1,df.shape[1]-1):
            fil.write(str(df.at[indx,df.columns[col]])+" | ")
        fil.write(str(df.at[indx,df.columns[df.shape[1]-1]]))
        fil.write("\n")

# %% [raw]
# !cat file_to_parse.csv
