# %% [markdown]
# https://pycallgraph.readthedocs.io/en/master/
#
# https://stackoverflow.com/questions/13963321/build-a-call-graph-in-python-including-modules-and-functions
#
# http://blog.prashanthellina.com/generating-call-graphs-for-understanding-and-refactoring-python-code.html

# %%
#!pycallgraph graphviz -- ./mypythonscript.py

# %%
# !pip install pycallgraph
# Out:
# Collecting pycallgraph
#   Downloading https://files.pythonhosted.org/packages/ca/2e/fafa56316bc2c5fbfbda898f964137c8b5ef33a876cb1f35a54ff6afbd60/pycallgraph-1.0.1.tar.gz
# Building wheels for collected packages: pycallgraph
#   Running setup.py bdist_wheel for pycallgraph ... done
#   Stored in directory: /home/jovyan/.cache/pip/wheels/8c/4b/98/80b30394d77899669da7b8502cbc890d0f35e469022a66eeb3
# Successfully built pycallgraph
# Installing collected packages: pycallgraph
# Successfully installed pycallgraph-1.0.1

# %%
from pycallgraph import PyCallGraph
from pycallgraph.output import GraphvizOutput

with PyCallGraph(output=GraphvizOutput()):
    def a_cool_func():
        print('i\'m a cool func')
        print_me('cool')
        # moar
        niiice()
    
    def niiice(iminng=1,mim=3):
        return
        
    def print_me(st):
        print("hello world")
    
    a_cool_func()
# Out:
# i'm a cool func
# hello world

# %%
from IPython.display import Image
Image("pycallgraph.png")
